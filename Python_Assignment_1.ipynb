# %% [markdown]
# # **Python Assignment 1: Data Structures - Strings & Tuples**

# %% [markdown]
# 1. **String Concatenation:**
# Write a Python program that takes two strings i.e string 1 “Hello ”, string 2 get name as
# input from the user and concatenates them together.
#  Display the concatenated string as
# the output.

# %%
string1="Hello "
string2=input("Enter your name:  ")
output=string1 + string2
print(output)
# Out:
# Enter your name:  Risana. R
# Hello Risana. R

# %% [markdown]
# **Here string1 is taken as hello and string 2 is actually input from the user so we have to use 'input' keyword.Then by using concatenate operator '+' both the strings from string1 and string2 get concatenated.When we run the code, string2 will appear as input statement then after the name given as input that will be taken to print statement. Hence output appeared.**

# %% [markdown]
# 2/1.Now concatenate string 3 “, welcome to Python programming” to the existing string and
# display the output string.

# %%
string3="Welcome to python programming"
print(output,",",string3)
# Out:
# Hello Risana. R , Welcome to python programming

# %% [markdown]
# **Here using ',' output of the above code and string3 is concatenated.**

# %% [markdown]
# 2. **String Slicing and Indexing:**
#
# Write a Python program using the above concatenated string as input and performs the
# following tasks:
#
# a. Print the first character of the string.

# %%
string4="Hello Risana. R , Welcome to python programming"
print(string4[0])
# Out:
# H

# %% [markdown]
# **The concatenated string of the above is taken as input,i.e "Hello Risana. R welcome to python programming"
# by using basic accessing method the first character of the input is extracted.**

# %% [markdown]
# b. Print the last character of the string.

# %%
string4="Hello Risana. R , Welcome to python programming"
print(string4[-1])
# Out:
# g

# %% [markdown]
# **Here also input is taken from the concatenated string of the above,i.e "Hello Risana. R welcome to python programming" and using negative indexing accessing method the last character is extracted.**

# %% [markdown]
# c. Print the first 5 characters of the string.

# %%
string4="Hello Risana. R , Welcome to python programming"
print(string4[0:5])
# Out:
# Hello

# %% [markdown]
#  **possitive indexing method (basic slicing) is used to extract first five characters, in the above code '0' indicates the first character and start of slicing '5' indicates the end of slicing so totaly from 0th index to 5th index that is first five characters are extracted from the string.**

# %% [markdown]
# d. Print the last 11 characters of the string.

# %%
print(string4[-11:])
# Out:
# programming

# %% [markdown]
# **Here negative indexing method is used, Since the question is to print last 11 characters, i omitted end here.**

# %% [markdown]
# e. Print the string in reverse.

# %%
print(string4[::-1])
# Out:
# gnimmargorp nohtyp ot emocleW , R .anasiR olleH

# %% [markdown]
# **For reversing the complete string we can use both reverse() keyword and negative indexing, here i used negative indexing method with omitting start and end.**

# %% [markdown]
# f. Use slicing and print the word “Python” from the existing string.

# %%
string4="Hello Risana. R , Welcome to python programming"
print(string4[-18:-12])
# Out:
# python

# %% [markdown]
# **For slicing i opted for negative indexing, since the word python is in mostly last part of the string, here i used start and end and omitted skip step.**

# %% [markdown]
# 3. **String Methods:**
# Write a Python program that takes a string, strM = “Python beginner tutorial” and
# perform the following tasks:
#
# a. Convert the sentence to uppercase.

# %%
strM="Python beginner tutorial"
print(strM.upper())
# Out:
# PYTHON BEGINNER TUTORIAL

# %% [markdown]
# **Here upper() string method is used to convert the complete sentence to uppercase.**

# %% [markdown]
# b. Convert the sentence to lowercase.

# %%
print(strM.lower())
# Out:
# python beginner tutorial

# %% [markdown]
# **Here lower() string method is used to convert complete sentence to lowercase.**

# %% [markdown]
# c. Use Capitalize and return the sentence to the original input form.

# %%
print(strM.title())
# Out:
# Python Beginner Tutorial

# %% [markdown]
# **Here title() string method is used to capitalize the first word and convert the sentence to input form.**

# %% [markdown]
# d. Count the total number of occurrences of character ‘t’ in the string.

# %%
print(strM.count('t'))
# Out:
# 3

# %% [markdown]
# **Here count() string method is used to count the occurence of the character 't' in the complete string.**

# %% [markdown]
# e. Replace all occurrences of “Python” with “Machine Learning” in the input string
# strM = “Python beginner tutorial”

# %%
print(strM.replace("Python","Machine Learning"))
# Out:
# Machine Learning beginner tutorial

# %% [markdown]
# **Here to replace python with machine learning, replace() keyword is used, it is a astring method using for replacing part of a string with another.**

# %% [markdown]
# **Tuples (Creation, Modification and Access) :**
#
# Create 1st tuple with values ->
# (10, 20, 30),
# 2nd tuple with values -> (40, 50, 60):

# %%
tup1=(10,20,30)
tup2=(40,50,60)
print(tup1)
print(tup2)
# Out:
# (10, 20, 30)
# (40, 50, 60)

# %% [markdown]
# **2Tuples named tup1 and tup2 are created.**

# %% [markdown]
# a. Concatenate the two tuples and store it in “t_combine”

# %%
t_combine=tup1+tup2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %% [markdown]
# **Two tuples are combined with concatenation operator'+'
# and stored as t_combine variable.**

# %% [markdown]
# b. Repeat the elements of “t_combine” 3 times

# %%
print(t_combine * 3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %% [markdown]
# **To repeat t_comibe elements 3 times '*'operator is used here.**

# %% [markdown]
# c. Access the 3rd element from “t_combine”

# %%
print(t_combine[2])
# Out:
# 30

# %% [markdown]
# **According to possitive indexing 3rd element of the tuple has index number 2, so to access 3rd element t_combine[2] is used.**

# %% [markdown]
# d. Access the first three elements from “t_combine”

# %%
print(t_combine[0:3])
# Out:
# (10, 20, 30)

# %% [markdown]
# **To access first 3 elements from t_combine possitive indexing slicing method is used here, start '0' and end '3' is assigned in the code. '0' index indicates 1st element of tuple.**

# %% [markdown]
# e. Access the last three elements from “t_combine”

# %%
print(t_combine[-3:-1])
# Out:
# (40, 50)

# %% [markdown]
# **The last 3 elements are accessed using negative indexing method, since those are last elements from tuple accessing through negative indexing is much simpler to code.**
